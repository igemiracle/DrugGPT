# %%
import pandas as pd
import numpy as np
from pathlib import Path
import sys
import logging
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import gc 

pd.set_option('display.max_columns', None)
plt.style.use('seaborn')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = [12, 8]

sys.path.append('../src')
from preprocessing import MIMICPreprocessor
# Out:
# /var/folders/96/2s64979965l0x1hmvz6rctxh0000gp/T/ipykernel_1715/3349198604.py:12: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
DATA_PATH = Path('../data')
PROCESSED_PATH = Path('../data/processed')
PROCESSED_PATH.mkdir(exist_ok=True)
RANDOM_SEED = 42

preprocessor = MIMICPreprocessor(DATA_PATH)

# %%
# 第1步：加载和处理 PATIENTS 表（较小的表）
print("Step 1: Processing PATIENTS table...")
try:
    patients_df = pd.read_csv(
        DATA_PATH / "PATIENTS.csv",
        usecols=['SUBJECT_ID', 'GENDER', 'DOB', 'DOD', 'DOD_HOSP', 'DOD_SSN', 'EXPIRE_FLAG'],
        dtype={
            'SUBJECT_ID': 'int32',
            'GENDER': 'category',
            'EXPIRE_FLAG': 'int8'
        }
    )
    patients_df = preprocessor.process_demographics(patients_df)
    print(f"Processed {len(patients_df)} patients")
    
    # 保存处理后的患者数据
    patients_df.to_pickle(PROCESSED_PATH / 'processed_patients.pkl')
    gc.collect()  # 清理内存
except Exception as e:
    print(f"Error processing PATIENTS: {str(e)}")
    raise
# Out:
# 2024-11-07 23:15:23,773 - INFO - Processing demographics data...
# Step 1: Processing PATIENTS table...
# 2024-11-07 23:15:24,384 - INFO -
# Demographic Processing Summary:
# 2024-11-07 23:15:24,384 - INFO - Total patients: 46520
# 2024-11-07 23:15:24,385 - INFO - Patients with accurate age (≤89): 28386
# 2024-11-07 23:15:24,385 - INFO - Patients with age >89 (marked as 90+): 18134
# Processed 46520 patients

# %%
# 第2步：分块处理 NOTEEVENTS 表
print("\nStep 2: Processing NOTEEVENTS table in chunks...")
try:
    chunk_size = 50000  # 可以根据内存调整
    notes_chunks = []
    
    for chunk in tqdm(pd.read_csv(
        DATA_PATH / "NOTEEVENTS.csv",
        usecols=['SUBJECT_ID', 'HADM_ID', 'CHARTDATE', 'CATEGORY', 'TEXT'],
        chunksize=chunk_size
    )):
        processed_chunk = preprocessor.clean_notes(chunk)
        notes_chunks.append(processed_chunk[['SUBJECT_ID', 'HADM_ID', 'cleaned_text', 'sections']])
        del chunk
        gc.collect()

    notes_df = pd.concat(notes_chunks, ignore_index=True)
    del notes_chunks
    gc.collect()
    
    # 保存处理后的临床记录
    notes_df.to_pickle(PROCESSED_PATH / 'processed_notes.pkl')
    print(f"Processed {len(notes_df)} clinical notes")
except Exception as e:
    print(f"Error processing NOTEEVENTS: {str(e)}")
    raise
# Out:
# Step 2: Processing NOTEEVENTS table in chunks...
# 0it [00:00, ?it/s]2024-11-07 23:15:31,882 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 1it [00:03,  3.74s/it]2024-11-07 23:15:33,451 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 2it [00:05,  2.46s/it]2024-11-07 23:15:33,757 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 3it [00:05,  1.48s/it]2024-11-07 23:15:33,926 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 4it [00:05,  1.04it/s]2024-11-07 23:15:34,089 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
#
# Extracting sections:  53%|███████▉       | 8427/15894 [00:02<00:02, 2843.85it/s]
# Extracting sections:  55%|████████▏      | 8739/15894 [00:02<00:02, 2925.22it/s]
# Extracting sections:  57%|████████▌      | 9057/15894 [00:02<00:02, 2999.61it/s]
# Extracting sections:  59%|████████▊      | 9364/15894 [00:03<00:02, 3019.37it/s]
# Extracting sections:  61%|█████████▏     | 9670/15894 [00:03<00:02, 3030.82it/s]
# Extracting sections:  63%|█████████▍     | 9974/15894 [00:03<00:01, 2963.77it/s]
# Extracting sections:  65%|█████████     | 10271/15894 [00:03<00:01, 2919.27it/s]
# Extracting sections:  66%|█████████▎    | 10564/15894 [00:03<00:01, 2864.07it/s]
# Extracting sections:  68%|█████████▌    | 10851/15894 [00:03<00:01, 2810.84it/s]
# Extracting sections:  70%|█████████▊    | 11133/15894 [00:03<00:01, 2787.89it/s]
# Extracting sections:  72%|██████████    | 11412/15894 [00:03<00:01, 2760.76it/s]
# Extracting sections:  74%|██████████▎   | 11689/15894 [00:03<00:01, 2732.77it/s]
# Extracting sections:  75%|██████████▌   | 11963/15894 [00:04<00:01, 2730.72it/s]
# Extracting sections:  77%|██████████▊   | 12247/15894 [00:04<00:01, 2762.60it/s]
# Extracting sections:  79%|███████████   | 12524/15894 [00:04<00:01, 2735.74it/s]
# Extracting sections:  81%|███████████▎  | 12817/15894 [00:04<00:01, 2791.29it/s]
# Extracting sections:  82%|███████████▌  | 13097/15894 [00:04<00:01, 2782.10it/s]
# Extracting sections:  84%|███████████▊  | 13380/15894 [00:04<00:00, 2795.64it/s]
# Extracting sections:  86%|████████████  | 13666/15894 [00:04<00:00, 2813.11it/s]
# Extracting sections:  88%|████████████▎ | 13948/15894 [00:04<00:00, 2806.51it/s]
# Extracting sections:  90%|████████████▌ | 14238/15894 [00:04<00:00, 2833.29it/s]
# Extracting sections:  91%|████████████▊ | 14534/15894 [00:04<00:00, 2870.51it/s]
# Extracting sections:  93%|█████████████ | 14838/15894 [00:05<00:00, 2920.88it/s]
# Extracting sections:  95%|█████████████▎| 15137/15894 [00:05<00:00, 2940.04it/s]
# Extracting sections:  97%|█████████████▌| 15447/15894 [00:05<00:00, 2985.71it/s]
# Extracting sections: 100%|██████████████| 15894/15894 [00:05<00:00, 2951.75it/s]
# /Users/jingl1/Documents/GitHub/DrugGPT/scripts/../src/preprocessing.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes_df['sections'] = notes_df['cleaned_text'].progress_apply(extract_sections)
# 10it [00:47,  8.43s/it]2024-11-07 23:16:17,255 - INFO - Starting clinical notes cleaning...
#
# Cleaning text:   0%|                                  | 0/15553 [00:00<?, ?it/s]
# Cleaning text:   3%|▌                     | 398/15553 [00:00<00:03, 3970.40it/s]
# Cleaning text:   5%|█▏                    | 796/15553 [00:00<00:03, 3697.22it/s]
# Cleaning text:   8%|█▌                   | 1203/15553 [00:00<00:03, 3856.81it/s]
# Cleaning text:  10%|██▏                  | 1597/15553 [00:00<00:03, 3887.96it/s]
# Cleaning text:  13%|██▋                  | 1987/15553 [00:00<00:03, 3848.33it/s]
# Cleaning text:  15%|███▏                 | 2375/15553 [00:00<00:03, 3856.07it/s]
# Extracting sections:  21%|███            | 3339/16244 [00:01<00:04, 2975.29it/s]
# Extracting sections:  23%|███▍           | 3656/16244 [00:01<00:04, 3033.10it/s]
# Extracting sections:  24%|███▋           | 3960/16244 [00:01<00:04, 2999.07it/s]
# Extracting sections:  26%|███▉           | 4261/16244 [00:01<00:04, 2953.13it/s]
# Extracting sections:  28%|████▏          | 4576/16244 [00:01<00:03, 3010.69it/s]
# Extracting sections:  30%|████▌          | 4900/16244 [00:01<00:03, 3077.95it/s]
# Extracting sections:  32%|████▊          | 5210/16244 [00:01<00:03, 3082.03it/s]
# Extracting sections:  34%|█████          | 5521/16244 [00:01<00:03, 3089.05it/s]
# Extracting sections:  36%|█████▍         | 5840/16244 [00:01<00:03, 3116.41it/s]
# ...
# Extracting sections:  76%|██████████▌   | 12402/16426 [00:03<00:01, 2930.75it/s]
# Extracting sections:  77%|██████████▊   | 12696/16426 [00:04<00:01, 2928.90it/s]
# Extracting sections:  79%|███████████   | 12997/16426 [00:04<00:01, 2949.27it/s]
# Extracting sections:  81%|███████████▎  | 13293/16426 [00:04<00:01, 2945.77it/s]
# Extracting sections:  83%|███████████▌  | 13588/16426 [00:04<00:00, 2943.25it/s]
# Extracting sections:  85%|███████████▊  | 13897/16426 [00:04<00:00, 2986.07it/s]
# Extracting sections:  87%|████████████  | 14223/16426 [00:04<00:00, 3065.66it/s]
# Extracting sections:  88%|████████████▍ | 14530/16426 [00:04<00:00, 3054.76it/s]
# Extracting sections:  90%|████████████▋ | 14836/16426 [00:04<00:00, 3017.43it/s]
# Extracting sections:  92%|████████████▉ | 15138/16426 [00:04<00:00, 2965.71it/s]
# Extracting sections:  94%|█████████████▏| 15435/16426 [00:05<00:00, 2918.94it/s]
# Extracting sections:  96%|█████████████▍| 15728/16426 [00:05<00:00, 2882.58it/s]
# Extracting sections:  98%|█████████████▋| 16017/16426 [00:05<00:00, 2875.84it/s]
# Extracting sections: 100%|██████████████| 16426/16426 [00:05<00:00, 3066.40it/s]
# /Users/jingl1/Documents/GitHub/DrugGPT/scripts/../src/preprocessing.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes_df['sections'] = notes_df['cleaned_text'].progress_apply(extract_sections)
# 14it [01:30, 10.18s/it]2024-11-07 23:16:59,877 - INFO - Starting clinical notes cleaning...
#
# Cleaning text:   0%|                                  | 0/10606 [00:00<?, ?it/s]
# Cleaning text:   4%|▊                     | 383/10606 [00:00<00:02, 3821.10it/s]
# Cleaning text:   7%|█▌                    | 766/10606 [00:00<00:02, 3800.53it/s]
# Cleaning text:  11%|██▎                  | 1147/10606 [00:00<00:02, 3743.10it/s]
# Cleaning text:  14%|███                  | 1522/10606 [00:00<00:02, 3724.20it/s]
# Cleaning text:  18%|███▊                 | 1905/10606 [00:00<00:02, 3759.91it/s]
# Cleaning text:  22%|████▌                | 2282/10606 [00:00<00:02, 3738.89it/s]
# Cleaning text:  25%|█████▎               | 2674/10606 [00:00<00:02, 3792.42it/s]
# Cleaning text:  29%|██████               | 3054/10606 [00:00<00:01, 3792.66it/s]
# Cleaning text:  32%|██████▊              | 3434/10606 [00:00<00:01, 3790.07it/s]
- INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 33it [01:49,  1.98it/s]2024-11-07 23:17:17,977 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 34it [01:49,  2.08it/s]2024-11-07 23:17:18,356 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 35it [01:50,  2.22it/s]2024-11-07 23:17:18,731 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 36it [01:50,  2.34it/s]2024-11-07 23:17:19,112 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 37it [01:50,  2.42it/s]2024-11-07 23:17:19,492 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 38it [01:51,  2.48it/s]2024-11-07 23:17:19,885 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 39it [01:51,  2.50it/s]2024-11-07 23:17:20,264 - INFO - Starting clinical notes cleaning...
#
# Cleaning text: 0it [00:00, ?it/s]
#
# Extracting sections: 0it [00:00, ?it/s]
# 40it [01:52,  2.54it/s]2024-11-07 23:17:20,707 - INFO - Starting clinical notes cleaning...
#
# Cleaning text:   0%|                                   | 0/1722 [00:00<?, ?it/s]
# Cleaning text:  27%|██████▎                | 468/1722 [00:00<00:00, 4672.86it/s]
# Cleaning text:  54%|████████████▌          | 936/1722 [00:00<00:00, 4467.80it/s]
# Cleaning text: 100%|██████████████████████| 1722/1722 [00:00<00:00, 4312.45it/s]
# /Users/jingl1/Documents/GitHub/DrugGPT/scripts/../src/preprocessing.py:316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes_df['cleaned_text'] = notes_df['TEXT'].progress_apply(clean_text)
# Extracting sections:   0%|                             | 0/1722 [00:00<?, ?it/s]
# Extracting sections:  21%|███▌             | 363/1722 [00:00<00:00, 3622.39it/s]
# Extracting sections:  42%|███████▏         | 726/1722 [00:00<00:00, 3519.59it/s]
# Extracting sections:  63%|██████████      | 1079/1722 [00:00<00:00, 3503.75it/s]
# Extracting sections: 100%|████████████████| 1722/1722 [00:00<00:00, 3348.74it/s]
# /Users/jingl1/Documents/GitHub/DrugGPT/scripts/../src/preprocessing.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes_df['sections'] = notes_df['cleaned_text'].progress_apply(extract_sections)
# 41it [01:53,  1.47it/s]2024-11-07 23:17:22,056 - INFO - Starting clinical notes cleaning...
#
# Cleaning text:   0%|                                   | 0/2789 [00:00<?, ?it/s]
# Cleaning text:  15%|███▎                   | 408/2789 [00:00<00:00, 4078.94it/s]
# Cleaning text:  30%|██████▊                | 824/2789 [00:00<00:00, 4122.11it/s]
# Cleaning text:  45%|█████████▉            | 1254/2789 [00:00<00:00, 4202.58it/s]
# Cleaning text:  60%|█████████████▎        | 1686/2789 [00:00<00:00, 4247.81it/s]
# Cleaning text:  76%|████████████████▋     | 2111/2789 [00:00<00:00, 4232.97it/s]
# Cleaning text: 100%|██████████████████████| 2789/2789 [00:00<00:00, 4159.56it/s]
# /Users/jingl1/Documents/GitHub/DrugGPT/scripts/../src/preprocessing.py:316: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes_df['cleaned_text'] = notes_df['TEXT'].progress_apply(clean_text)
#
# Extracting sections:   0%|                             | 0/2789 [00:00<?, ?it/s]
# Extracting sections:  11%|█▉               | 314/2789 [00:00<00:00, 3139.03it/s]
# Extracting sections:  23%|███▊             | 628/2789 [00:00<00:00, 3092.80it/s]
# Extracting sections:  34%|█████▊           | 959/2789 [00:00<00:00, 3185.36it/s]
# Extracting sections:  47%|███████▍        | 1298/2789 [00:00<00:00, 3262.87it/s]
# Extracting sections:  58%|█████████▎      | 1625/2789 [00:00<00:00, 3254.05it/s]
# Extracting sections:  70%|███████████▏    | 1951/2789 [00:00<00:00, 3250.43it/s]
# Extracting sections:  82%|█████████████   | 2277/2789 [00:00<00:00, 3200.41it/s]
# Extracting sections: 100%|████████████████| 2789/2789 [00:00<00:00, 3184.06it/s]
# /Users/jingl1/Documents/GitHub/DrugGPT/scripts/../src/preprocessing.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   notes_df['sections'] = notes_df['cleaned_text'].progress_apply(extract_sections)
# 42it [01:55,  2.75s/it]
# Processed 141624 clinical notes

# %%
# 第3步：分块处理 PRESCRIPTIONS 表
print("\nStep 3: Processing PRESCRIPTIONS table in chunks...")
try:
    chunk_size = 100000  # 可以根据内存调整
    prescription_chunks = []
    
    for chunk in tqdm(pd.read_csv(
        DATA_PATH / "PRESCRIPTIONS.csv",
        usecols=['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'ROUTE', 
                 'DOSE_VAL_RX', 'DOSE_UNIT_RX'],
        dtype={
            'SUBJECT_ID': 'int32',
            'HADM_ID': 'int32',
            'DRUG': 'category',
            'ROUTE': 'category',
            'DOSE_UNIT_RX': 'category'
        },
        chunksize=chunk_size
    )):
        processed_chunk = preprocessor.process_prescriptions(chunk)
        prescription_chunks.append(processed_chunk)
        del chunk
        gc.collect()

    prescriptions_df = pd.concat(prescription_chunks, ignore_index=True)
    del prescription_chunks
    gc.collect()
    
    # 保存处理后的处方数据
    prescriptions_df.to_pickle(PROCESSED_PATH / 'processed_prescriptions.pkl')
    print(f"Processed {len(prescriptions_df)} prescriptions")
except Exception as e:
    print(f"Error processing PRESCRIPTIONS: {str(e)}")
    raise
# Out:
# Step 3: Processing PRESCRIPTIONS table in chunks...
# 0it [00:00, ?it/s]2024-11-07 23:17:24,295 - INFO - Processing prescription data...
# 2024-11-07 23:17:25,865 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:25,865 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:25,866 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 1it [00:01,  1.73s/it]2024-11-07 23:17:26,019 - INFO - Processing prescription data...
# 2024-11-07 23:17:27,602 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:27,603 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:27,603 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 2it [00:03,  1.73s/it]2024-11-07 23:17:27,754 - INFO - Processing prescription data...
# 2024-11-07 23:17:29,343 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:29,344 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:29,344 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 3it [00:05,  1.74s/it]2024-11-07 23:17:29,493 - INFO - Processing prescription data...
# 2024-11-07 23:17:31,087 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:31,088 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:31,088 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 4it [00:06,  1.74s/it]2024-11-07 23:17:31,240 - INFO - Processing prescription data...
# 2024-11-07 23:17:32,824 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:32,824 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:32,824 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 5it [00:08,  1.74s/it]2024-11-07 23:17:32,976 - INFO - Processing prescription data...
# 2024-11-07 23:17:34,564 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:34,565 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:34,565 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 6it [00:10,  1.74s/it]2024-11-07 23:17:34,719 - INFO - Processing prescription data...
# 2024-11-07 23:17:36,308 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:36,308 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:36,309 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 7it [00:12,  1.74s/it]2024-11-07 23:17:36,460 - INFO - Processing prescription data...
# 2024-11-07 23:17:38,038 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:38,039 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:38,039 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 8it [00:13,  1.74s/it]2024-11-07 23:17:38,192 - INFO - Processing prescription data...
# 2024-11-07 23:17:39,765 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:39,766 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:39,766 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 9it [00:15,  1.73s/it]2024-11-07 23:17:39,923 - INFO - Processing prescription data...
# 2024-11-07 23:17:41,500 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:41,500 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:41,501 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 10it [00:17,  1.73s/it]2024-11-07 23:17:41,650 - INFO - Processing prescription data...
# 2024-11-07 23:17:43,223 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:43,223 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:43,224 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 11it [00:19,  1.73s/it]2024-11-07 23:17:43,374 - INFO - Processing prescription data...
# 2024-11-07 23:17:44,945 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:44,945 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:44,945 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 12it [00:20,  1.73s/it]2024-11-07 23:17:45,097 - INFO - Processing prescription data...
# 2024-11-07 23:17:46,684 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:46,684 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:46,684 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 13it [00:22,  1.73s/it]2024-11-07 23:17:46,844 - INFO - Processing prescription data...
# 2024-11-07 23:17:48,426 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:48,427 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:48,427 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 14it [00:24,  1.73s/it]2024-11-07 23:17:48,577 - INFO - Processing prescription data...
# 2024-11-07 23:17:50,160 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:50,161 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:50,161 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 15it [00:26,  1.74s/it]2024-11-07 23:17:50,315 - INFO - Processing prescription data...
# 2024-11-07 23:17:51,907 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:51,908 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:51,908 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 16it [00:27,  1.74s/it]2024-11-07 23:17:52,064 - INFO - Processing prescription data...
# 2024-11-07 23:17:53,655 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:53,655 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:53,656 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 17it [00:29,  1.74s/it]2024-11-07 23:17:53,813 - INFO - Processing prescription data...
# 2024-11-07 23:17:55,418 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:55,418 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:55,418 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 18it [00:31,  1.75s/it]2024-11-07 23:17:55,574 - INFO - Processing prescription data...
# 2024-11-07 23:17:57,159 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:57,160 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:57,160 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 19it [00:33,  1.75s/it]2024-11-07 23:17:57,312 - INFO - Processing prescription data...
# 2024-11-07 23:17:58,887 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:17:58,888 - INFO - Available columns after prescription processing:
# 2024-11-07 23:17:58,888 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 20it [00:34,  1.74s/it]2024-11-07 23:17:59,039 - INFO - Processing prescription data...
# 2024-11-07 23:18:00,624 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:18:00,625 - INFO - Available columns after prescription processing:
# 2024-11-07 23:18:00,625 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 21it [00:36,  1.74s/it]2024-11-07 23:18:00,785 - INFO - Processing prescription data...
# 2024-11-07 23:18:02,379 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:18:02,380 - INFO - Available columns after prescription processing:
# 2024-11-07 23:18:02,380 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 22it [00:38,  1.74s/it]2024-11-07 23:18:02,535 - INFO - Processing prescription data...
# 2024-11-07 23:18:04,120 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:18:04,121 - INFO - Available columns after prescription processing:
# 2024-11-07 23:18:04,121 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 23it [00:39,  1.74s/it]2024-11-07 23:18:04,276 - INFO - Processing prescription data...
# 2024-11-07 23:18:05,873 - INFO - Processed 100000 prescriptions
# 2024-11-07 23:18:05,873 - INFO - Available columns after prescription processing:
# 2024-11-07 23:18:05,873 - INFO - ['SUBJECT_ID', 'HADM_ID', 'STARTDATE', 'ENDDATE', 'DRUG', 'DOSE_VAL_RX', 'DOSE_UNIT_RX', 'ROUTE', 'DURATION', 'DRUG_NAME_GENERIC', 'drug_id']
# 24it [00:41,  1.75s/it]

# %%
# 第4步：处理 DIAGNOSES_ICD 表
print("\nStep 4: Processing DIAGNOSES_ICD table...")
try:
    diagnoses_df = pd.read_csv(
        DATA_PATH / "DIAGNOSES_ICD.csv",
        usecols=['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE'],
        dtype={
            'SUBJECT_ID': 'int32',
            'HADM_ID': 'int32',
            'ICD9_CODE': 'category'
        }
    )
    diagnoses_df.to_pickle(PROCESSED_PATH / 'processed_diagnoses.pkl')
    print(f"Processed {len(diagnoses_df)} diagnoses")
except Exception as e:
    print(f"Error processing DIAGNOSES_ICD: {str(e)}")
    raise
# Out:
# Step 4: Processing DIAGNOSES_ICD table...
# Processed 651047 diagnoses

# %%
# 第5步：分析和可视化（可选，根据需要运行）
def analyze_processed_data():
    print("\nAnalyzing processed data...")
    
    # 加载处理后的数据
    patients_df = pd.read_pickle(PROCESSED_PATH / 'processed_patients.pkl')
    
    # 绘制人口统计图
    plot_demographics(patients_df)
    
    # 分析处方数据（使用样本以节省内存）
    prescriptions_df = pd.read_pickle(PROCESSED_PATH / 'processed_prescriptions.pkl')
    prescription_sample = prescriptions_df.sample(n=min(100000, len(prescriptions_df)))
    plot_prescriptions_summary(prescription_sample)
    del prescription_sample
    gc.collect()
    
    # 分析临床记录
    notes_df = pd.read_pickle(PROCESSED_PATH / 'processed_notes.pkl')
    analyze_notes_summary(notes_df.sample(n=min(10000, len(notes_df))))

# %%
# 第6步：分块合并数据（如果需要）
def merge_data_in_chunks():
    print("\nMerging data in chunks...")
    
    chunk_size = 50000  # 可以调整
    merged_chunks = []
    
    notes_df = pd.read_pickle(PROCESSED_PATH / 'processed_notes.pkl')
    patients_df = pd.read_pickle(PROCESSED_PATH / 'processed_patients.pkl')
    diagnoses_df = pd.read_pickle(PROCESSED_PATH / 'processed_diagnoses.pkl')
    
    for chunk in tqdm(np.array_split(notes_df, len(notes_df) // chunk_size + 1)):
        # 读取对应的处方数据
        prescriptions_chunk = pd.read_pickle(PROCESSED_PATH / 'processed_prescriptions.pkl')
        
        merged_chunk = preprocessor.merge_patient_data(
            chunk,
            prescriptions_chunk,
            diagnoses_df,
            patients_df
        )
        merged_chunks.append(merged_chunk)
        del chunk, prescriptions_chunk
        gc.collect()
    
    merged_df = pd.concat(merged_chunks, ignore_index=True)
    del merged_chunks
    gc.collect()
    
    return merged_df

# %%
try:
    merged_df = merge_data_in_chunks()
    train_df, test_df = preprocessor.create_train_test_split(merged_df)

except Exception as e:
    print(f"Error during analysis: {str(e)}")
    raise
# Out:
# Error during analysis: name 'merge_data_in_chunks' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 try:
# ----> 2     merged_df = merge_data_in_chunks()
#       3     train_df, test_df = preprocessor.create_train_test_split(merged_df)
#       5 except Exception as e:
#
# NameError: name 'merge_data_in_chunks' is not defined

# %%
       # 分块保存
        chunk_size = 100000
        print("Saving training data in chunks...")
        for i, chunk in enumerate(np.array_split(train_df, len(train_df) // chunk_size + 1)):
            chunk.to_csv(PROCESSED_PATH / f'train_data_chunk_{i}.csv', index=False)
            
        print("Saving test data in chunks...")
        for i, chunk in enumerate(np.array_split(test_df, len(test_df) // chunk_size + 1)):
            chunk.to_csv(PROCESSED_PATH / f'test_data_chunk_{i}.csv', index=False)
            
        print("\nProcessing completed successfully!")
        print(f"Training set size: {len(train_df)}")
        print(f"Test set size: {len(test_df)}")
        print(f"Data saved to: {PROCESSED_PATH}")
        
    except Exception as e:
        print(f"Error during processing: {str(e)}")
        raise
